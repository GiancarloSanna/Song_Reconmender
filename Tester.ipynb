# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd
from random import randint
from time import sleep
from itertools import islice
from pandas import json_normalize

# %%
test = pd.read_csv('./Data/part20.csv')
test.tail(50)
# Out:
#                                      uri  \
# 50  spotify:track:683hRieVmYdAhVA1DkjSAk
# 51  spotify:track:7HKez549fwJQDzx3zLjHKC
# 52  spotify:track:61T2H6w0ggQdhCvVegLl99
# 53  spotify:track:5dulYd9AKIprMoF837OTDb
# 54  spotify:track:2GyA33q5rti5IxkMQemRDH
# 55  spotify:track:2TfSHkHiFO4gRztVIkggkE
# 56  spotify:track:7s0lDK7y3XLmI7tcsRAbW0
# 57  spotify:track:6e13443Ve7RGcAUScTgYtl
# 58  spotify:track:3Q4WeJmzxuDpzMu9QjQqbM
# 59  spotify:track:7k4uHnOdJViC6EBvcvzJZJ
# 60  spotify:track:3qP5nPy0qh7iodfLMBsfbr
# 61  spotify:track:3UZ9aPaYlBBlAvpdh3kK0U
# 62  spotify:track:5OwOWdY2hsSAtSERkxUwoc
# 63  spotify:track:5Ao3vArhHOJBFvr7DjxBki
# 64  spotify:track:6hIS1u7nuJmFE12rXAPMxm
# 65  spotify:track:6rqxivjFHp8K0yMiefG56g
# 66  spotify:track:1TKlBK9cSrM5u4CiL4SETS
# 67  spotify:track:4wFUdSCer8bdQsrp1M90sa
# 68  spotify:track:5jROdl6MhcmP3O7h2sVgtw
# 69  spotify:track:6E9V9TRlVOLjenGjHemzEH
# 70  spotify:track:5aj0xPGiEUN3aI2oOYu14S
# 71  spotify:track:4A6IgELhUNZIJ38kMUB4pC
# ...
