# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd
from random import randint
from time import sleep
from itertools import islice
from pandas import json_normalize

# %%
test = pd.read_csv('./Data/part59.csv')
test.head(50)
# Out:
#                                      uri  \
# 0   spotify:track:47LHkzmcY4vnx69offVQ2Q
# 1   spotify:track:2bbhyUWJ5VjdfI3P4PRLu2
# 2   spotify:track:42YgaJLCehufTbH2orwBHM
# 3   spotify:track:5Hd6DPGjqihEnWSiGRzqr6
# 4   spotify:track:1HWQe9TChfNPt7I7ojbqjK
# 5   spotify:track:4iEOVEULZRvmzYSZY2ViKN
# 6   spotify:track:0HV1cGoX5ASBlPA1pqH8fG
# 7   spotify:track:0ZrRfFSH6kNp62zUXMDOlu
# 8   spotify:track:2SZwg0hZD1hWoCIG9p2XRn
# 9   spotify:track:3IFo5x0HWlvRu0QIAtefor
# 10  spotify:track:1Hs085AOaoXrknVZExcE80
# 11  spotify:track:7hpxYEXTBQOAcXBJLgQIV2
# 12  spotify:track:01C6oknRM4lN0W9KXy6r26
# 13  spotify:track:1C2QJNTmsTxCDBuIgai8QV
# 14  spotify:track:4LgIcna8LRrR3DOomihYMY
# 15  spotify:track:1wHSxWBfPr3GO31y8KGrWe
# 16  spotify:track:0Yj7WP1MbAqQVQA5Na4I7E
# 17  spotify:track:3ewKQAIFCLDk0mbhV0HjWE
# 18  spotify:track:3m86z31Y6Gns8QyZcgQaSa
# 19  spotify:track:5OqxuHIu8yCJkMIFW6SaGg
# 20  spotify:track:5cxRbfQWrT4NZ2msbtSx4H
# 21  spotify:track:0Zw4llKeB35SIKASy1aLtV
# ...
